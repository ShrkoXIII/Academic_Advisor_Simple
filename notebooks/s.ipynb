# %%
import pandas as pd 
df=pd.read_parquet(r'D:\AI\Real projects\Academic_Advisor_Simple\data\raw\v_acs_grade.parquet')

# %%
pd.set_option('display.max_columns',100)

# %%
df
# Out:
#     grade_id  grade_version_id grade_name_sl       version_title_sl  \
# 0    673.111             2.111           شرف  القرار الوزاري الموحد
# 1    999.111             1.111           NaN          تأسيس الجامعة
# 2    974.111             3.111           شرف         القرار رقم 230
# 3    975.111             3.111           شرف         القرار رقم 230
# 4     85.111             1.111         ممتاز          تأسيس الجامعة
# ..       ...               ...           ...                    ...
# 67  1004.111             3.111           NaN         القرار رقم 230
# 68  1006.111             2.111           NaN  القرار الوزاري الموحد
# 69  1007.111             2.111           NaN  القرار الوزاري الموحد
# 70  1009.111             1.111           NaN          تأسيس الجامعة
# 71  1005.111             3.111           NaN         القرار رقم 230
#
#    version_number  from_percent  to_percent  points finish_status grade_show  \
# ...

# %%
df[df['grade_version_id']==3.111]
# Out:
#     grade_id  grade_version_id                                grade_name_sl  \
# 2    974.111             3.111                                          شرف
# 3    975.111             3.111                                          شرف
# 8    976.111             3.111                                       امتياز
# 10   977.111             3.111                                       امتياز
# 12   978.111             3.111                                     جيد جداً
# 17   979.111             3.111                                     جيد جداً
# 20   980.111             3.111                                          جيد
# 22   981.111             3.111                                          جيد
# 26   982.111             3.111                                        مقبول
# 27   983.111             3.111                                    نجاح شرطي
# 30   984.111             3.111                                    نجاح شرطي
# ...

# %%
df['observed_gap_semesters'].value_counts(dropna=False)
# Out:
# observed_gap_semesters
# 0       384164
# <NA>     68510
# 1         3267
# 2          386
# 3           88
# 4           31
# 5            7
# Name: count, dtype: Int64

# %% [markdown]
# 10815.111
# 3472.111
# 3470.111

# %%
df[df['total_fail_credits']==713.5]
# Out:
#        student_course_id student_id course_id  part_id grade_id  final_mark  \
# 439608       2573279.111   3470.111  1093.111    20232  978.111          81
# 439609       2201832.111   3470.111   664.111    20213  974.111          99
# 439610       1549096.111   3470.111   689.111    20203  982.111          60
# 439612       1549095.111   3470.111   690.111    20203  983.111          59
# 439614       1559322.111   3470.111   696.111    20211  981.111          67
# 439618       1559323.111   3470.111   699.111    20211  981.111          66
# 439619       1559324.111   3470.111   709.111    20211  981.111          67
#
#         points       course_name_sl degree_id degree_name_sl_course  \
# 439608     3.0      الامتحان الوطني     2.111         دكتور في الطب
# 439609     4.0         رسالة التخرج     2.111         دكتور في الطب
# 439610     2.0  الأحياء الدقيقة (1)     2.111         دكتور في الطب
# 439612    1.75  الأحياء الدقيقة (2)     2.111         دكتور في الطب
# ...

# %%
df.describe()
# Out:
#             part_id  final_mark    points  course_credits  attempt_number  \
# count      456453.0    456453.0  456453.0        456453.0        456453.0
# mean   20226.812254   69.977336  2.316207        2.896384        1.123636
# std       16.522975   15.944697  0.974245        1.444591        0.436635
# min         20201.0         0.0       0.0             0.0             1.0
# 25%         20212.0        60.0       2.0             2.0             1.0
# 50%         20231.0        71.0       2.5             3.0             1.0
# 75%         20241.0        82.0       3.0             3.0             1.0
# max         20253.0       100.0       4.0            24.0            11.0
#
#        start_part_id  finish_part_id  prev_gpa_points  last_enrolled_gpa  \
# count       456453.0        197427.0         412163.0           411686.0
# mean    20202.562855    20233.589575         2.247115           2.263896
# std         26.39864       13.013039         0.836638           0.815299
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 456453 entries, 0 to 456452
# Data columns (total 62 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   student_course_id         456453 non-null  string
#  1   student_id                456453 non-null  string
#  2   course_id                 456453 non-null  string
#  3   part_id                   456453 non-null  Int64
#  4   grade_id                  456453 non-null  string
#  5   final_mark                456453 non-null  Int64
#  6   points                    456453 non-null  Float64
#  7   course_name_sl            456453 non-null  string
#  8   degree_id                 456453 non-null  string
#  9   degree_name_sl_course     456453 non-null  string
#  10  faculty_id                456453 non-null  string
#  11  course_credits            456453 non-null  Float64
#  12  course_outcome_status     456453 non-null  str
# ...
