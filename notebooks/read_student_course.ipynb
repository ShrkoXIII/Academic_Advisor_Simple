# %%
import pandas as pd 
from paths import CLEAN_DIR
df=pd.read_parquet(CLEAN_DIR / "student_course.parquet")

# %%
pd.set_option("display.max_columns", 25)

# %%
df.columns
# Out:
# Index(['student_course_id', 'student_id', 'course_id', 'part_id', 'grade_id',
#        'final_mark', 'points', 'finish_status', 'course_name_sl',
#        'register_status', 'in_credits', 'in_gpa', 'in_agpa', 'study_mode',
#        'degree_id', 'student_name_sl', 'degree_name_sl', 'faculty_id',
#        'course_credits', 'active', 'course_outcome_status', 'attempt_number'],
#       dtype='str')

# %%
df
# Out:
#        student_course_id student_id course_id  part_id grade_id  final_mark  \
# 0            1430270.111  10002.111   437.111    20201  983.111          58
# 1            1430266.111  10002.111   520.111    20201  980.111          73
# 2            1430271.111  10002.111   531.111    20201  976.111          90
# 3            1430269.111  10002.111   536.111    20201  981.111          66
# 4            1430272.111  10002.111   542.111    20201  980.111          71
# ...                  ...        ...       ...      ...      ...         ...
# 459624       1612735.111   9998.111   361.111    20211  980.111          71
# 459625       2010887.111   9998.111   362.111    20212  981.111          67
# 459626       1407984.111   9998.111   364.111    20201  981.111          67
# 459627       1545153.111   9998.111   365.111    20203  982.111          64
# 459628       2010888.111   9998.111   366.111    20212  981.111          68
#
# ...

# %%
df['in_credits']
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 459629 entries, 0 to 459628
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   student_course_id      459629 non-null  string
#  1   student_id             459629 non-null  string
#  2   course_id              459629 non-null  string
#  3   part_id                459629 non-null  Int64
#  4   grade_id               459629 non-null  string
#  5   final_mark             459629 non-null  Int64
#  6   points                 459629 non-null  Float64
#  7   finish_status          459629 non-null  string
#  8   course_name_sl         459629 non-null  str
#  9   register_status        459629 non-null  string
#  10  in_credits             459629 non-null  str
#  11  in_gpa                 459629 non-null  str
#  12  in_agpa                459629 non-null  str
#  13  study_mode             459629 non-null  str
# ...

# %%
df['attempt_number'].value_counts()
# Out:
# attempt_number
# 1     415904
# 2      34178
# 3       6906
# 4       1842
# 5        540
# 6        172
# 7         56
# 8         24
# 9          4
# 10         2
# 11         1
# Name: count, dtype: Int64

# %%
finish_status | register_status |active |in_agpa |in_gpa|in_credits
